# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('file:///D:/Data%20Science%20&%20AI/Praxis%20Data%20Science/Projects%20Praxis/Machine%20Learning%20Project/laptop-price-predictor-regression-project-main/laptop-price-predictor-regression-project-main/laptop_data.csv')
print('No of instances before removing duplicates :',df.shape)
df.drop_duplicates
print('No of instances after removing duplicates :',df.shape)
df.head()
# Out:
# No of instances before removing duplicates : (1303, 12)
# No of instances after removing duplicates : (1303, 12)
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %% [markdown]
# # Defining Business Problems

# %% [markdown]
# # solving the laptop price prediction problem can help address business challenges-

# %% [markdown]
# # Pricing Optimization: By accurately predicting laptop prices, businesses can optimize their pricing strategies.

# %% [markdown]
# # Market Positioning: Price prediction can assist businesses in positioning their laptops in the market.

# %% [markdown]
# # Competitive Analysis: Price prediction can help businesses gain a competitive advantage by understanding the pricing strategies of their competitors.

# %%
#1.Q-What should be the optimal price for a laptop?
#2.Q-What factors influence the pricing of brand laptops?:?
#3-Q-How can accurate laptop price predictions benefit our brand?:

# %% [markdown]
# # Identify Features Available In This Dataset

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %% [raw]
# Unamed:0-Useless column,we will remove it.
# Company-Brand of laptop.
# TypeName-laptop Model Type.
# Inches-Screen Size.
# ScreenResol-ScreenPixel.
# Cpu-Processor.
# Ram-Ram in laptop.
# Memory-Memory of laptop.
# Opsys-Operating System.
# Weight-Weight of Laptop.
# Price-Target Variable and price of laptop.

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.describe(include='number')
# Out:
#        Unnamed: 0       Inches          Price
# count  1303.00000  1303.000000    1303.000000
# mean    651.00000    15.017191   59870.042910
# std     376.28801     1.426304   37243.201786
# min       0.00000    10.100000    9270.720000
# 25%     325.50000    14.000000   31914.720000
# 50%     651.00000    15.600000   52054.560000
# 75%     976.50000    15.600000   79274.246400
# max    1302.00000    18.400000  324954.720000

# %%
df.describe(exclude='number')
# Out:
#        Company  TypeName   ScreenResolution                         Cpu   Ram  \
# count     1303      1303               1303                        1303  1303
# unique      19         6                 40                         118     9
# top       Dell  Notebook  Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# freq       297       727                507                         190   619
#
#            Memory                    Gpu       OpSys Weight
# count        1303                   1303        1303   1303
# unique         39                    110           9    179
# top     256GB SSD  Intel HD Graphics 620  Windows 10  2.2kg
# freq          412                    281        1072    121

# %% [raw]
# At a glance
# Top Selling laptop brand is Dell
# i5 is most demanding laptops

# %% [markdown]
# ### Remove useless column

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
# Removing strings from continous columns
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
#Changing Datatype
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')

# %% [markdown]
# # Univariate Analysis

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['OpSys'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Memory'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # Bivariate Analysis

# %%
import seaborn as sns
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ## Q.Which Type of laptop model is costliest

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['ScreenResolution'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
df['Ips'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %% [markdown]
# ## Q.Does Display Quality matter to influence the price?

# %%
sns.barplot(x=df['Ips'],y=df['Price'])
# Out:
# <Axes: xlabel='Ips', ylabel='Price'>

# %%
new = df['ScreenResolution'].str.split('x',n=1,expand=True)
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
##Removing strings
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
#Converting datatype after removing string
df['X_res'] = df['X_res'].astype('int')
df['Y_res'] = df['Y_res'].astype('int')

# %%
#create new variable
df['pixel_per_inch'] = (((df['X_res']**2) + (df['Y_res']**2))**0.5/df['Inches']).astype('float')

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
##Removing strings
df['Cpu Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
def fetch_processor(text):
    if text in ['Intel Core i7', 'Intel Core i5', 'Intel Core i3']:
        return text
    elif text.startswith('Intel'):
        return 'Other Intel Processor'
    else:
        return 'AMD Processor'

# %%
df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor)

# %% [markdown]
# ## Q.Which Cpu brand is costly

# %%
sns.barplot(x=df['Cpu brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
#Costilest cpu is i7

# %%
df.drop(columns=['Cpu','Cpu Name'],inplace=True)

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

# %%
df["first"]= new[0]
df["first"]=df["first"].str.strip()
df["second"]= new[1]
df["second"]=df["second"].str.strip()

# %%
df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# %%
df['first'] = df['first'].str.replace(r'\D', '')
df["second"].fillna("0", inplace = True)
# Out:
# C:\Users\dipam\AppData\Local\Temp\ipykernel_9980\1886232230.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['first'] = df['first'].str.replace(r'\D', '')

# %%
df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# %%
df['first'] = df['first'].str.replace(r'\D', '')
df["second"].fillna("0", inplace = True)
df['second'] = df['second'].str.replace(r'\D', '')
df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)
# Out:
# C:\Users\dipam\AppData\Local\Temp\ipykernel_9980\1722179381.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['first'] = df['first'].str.replace(r'\D', '')
# C:\Users\dipam\AppData\Local\Temp\ipykernel_9980\1722179381.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['second'] = df['second'].str.replace(r'\D', '')

# %%
df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
#df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
#All widnows in windows category and mac in one category rest is others
def cat_os(inp):
    os_mapping = {
        'Windows 10': 'Windows',
        'Windows 7': 'Windows',
        'Windows 10 S': 'Windows',
        'macOS': 'Mac',
        'Mac OS X': 'Mac'
    }
    return os_mapping.get(inp, 'Others/No OS/Linux')

# %%
df['os'] = df['OpSys'].apply(cat_os)

# %%
df.drop(columns=['OpSys'],inplace=True)

# %% [markdown]
# ## Q.Which os laptops are most costly

# %%
sns.barplot(x=df['os'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.dtypes
# Out:
# Company            object
# TypeName           object
# Inches            float64
# Ram                 int32
# Gpu                object
# Weight            float32
# Price             float64
# Touchscreen         int64
# Ips                 int64
# X_res               int32
# Y_res               int32
# pixel_per_inch    float64
# Cpu brand          object
# os                 object
# dtype: object

# %%
cont_col1=list(df[df.dtypes[df.dtypes=='int32'].index].columns)
cont_col2=list(df[df.dtypes[df.dtypes=='float64'].index].columns)
cont_col3=list(df[df.dtypes[df.dtypes=='int64'].index].columns)
cont_col4=list(df[df.dtypes[df.dtypes=='float32'].index].columns)
all_cont=cont_col1+cont_col2+cont_col3+cont_col4

# %%
all_cont
# Out:
# ['Ram',
#  'X_res',
#  'Y_res',
#  'Inches',
#  'Price',
#  'pixel_per_inch',
#  'Touchscreen',
#  'Ips',
#  'Weight']

# %%
fig, axes = plt.subplots(len(all_cont), 1, figsize=(7, 5*len(all_cont)))

for i, col in enumerate(all_cont):
    sns.distplot(df[col], ax=axes[i])

plt.tight_layout()
plt.show()
# Out:
# C:\Users\dipam\AppData\Local\Temp\ipykernel_9980\1024720728.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], ax=axes[i])
# C:\Users\dipam\AppData\Local\Temp\ipykernel_9980\1024720728.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], ax=axes[i])
# C:\Users\dipam\AppData\Local\Temp\ipykernel_9980\1024720728.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], ax=axes[i])
# C:\Users\dipam\AppData\Local\Temp\ipykernel_9980\1024720728.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], ax=axes[i])
# C:\Users\dipam\AppData\Local\Temp\ipykernel_9980\1024720728.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], ax=axes[i])
# C:\Users\dipam\AppData\Local\Temp\ipykernel_9980\1024720728.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], ax=axes[i])
# C:\Users\dipam\AppData\Local\Temp\ipykernel_9980\1024720728.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], ax=axes[i])
# C:\Users\dipam\AppData\Local\Temp\ipykernel_9980\1024720728.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], ax=axes[i])
# C:\Users\dipam\AppData\Local\Temp\ipykernel_9980\1024720728.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], ax=axes[i])

# %% [markdown]
# # Checking Missing values

# %%
df.isnull().sum()
# Out:
# Company           0
# TypeName          0
# Inches            0
# Ram               0
# Gpu               0
# Weight            0
# Price             0
# Touchscreen       0
# Ips               0
# X_res             0
# Y_res             0
# pixel_per_inch    0
# Cpu brand         0
# os                0
# dtype: int64

# %%
#nothing found

# %% [markdown]
# # Outlier Checking and Treatment

# %%
all_cont
# Out:
# ['Ram',
#  'X_res',
#  'Y_res',
#  'Inches',
#  'Price',
#  'pixel_per_inch',
#  'Touchscreen',
#  'Ips',
#  'Weight']

# %%
sns.boxplot(data=df['Ram'],orient='hue')
# Out:
# <Axes: >

# %%
sns.boxplot(data=df['Ram'],orient='hue')
# Out:
# <Axes: >

# %%
def outlier_findings(inpdata):
    quantile1, quantile3= np.percentile(inpdata,[25,75])
    print('Quartile 1 :',quantile1,'Quartile 3 :',quantile3)
    iqr_value=quantile3-quantile1
    
    print("Inter Quartile Range :",iqr_value)
    lower_bound_val = quantile1 -(1.5 * iqr_value) 
    upper_bound_val = quantile3 +(1.5 * iqr_value) 
    
    print("Min Whisker :",lower_bound_val,"Max Whiker :",upper_bound_val)
    lower_outliers = np.where(inpdata < lower_bound_val)
    upper_outliers = np.where(inpdata > upper_bound_val)
    
    print("Number of values below the lower bound:", len(lower_outliers[0]))
    print("Number of values above the upper bound:", len(upper_outliers[0]))

# %%
outlier_findings(inpdata=df['Ram'])
# Out:
# Quartile 1 : 4.0 Quartile 3 : 8.0
# Inter Quartile Range : 4.0
# Min Whisker : -2.0 Max Whiker : 14.0
# Number of values below the lower bound: 0
# Number of values above the upper bound: 221

# %%
outlier_findings(inpdata=df['Inches'])
# Out:
# Quartile 1 : 14.0 Quartile 3 : 15.6
# Inter Quartile Range : 1.5999999999999996
# Min Whisker : 11.600000000000001 Max Whiker : 18.0
# Number of values below the lower bound: 38
# Number of values above the upper bound: 1

# %%
outlier_findings(inpdata=df['Weight'])
# Out:
# Quartile 1 : 1.5 Quartile 3 : 2.299999952316284
# Inter Quartile Range : 0.7999999523162842
# Min Whisker : 0.30000007152557373 Max Whiker : 3.4999998807907104
# Number of values below the lower bound: 0
# Number of values above the upper bound: 46

# %% [markdown]
# ### Treating outliers with winsorization technique

# %% [raw]
# We can impute outliers in various way like mean/median imputation,Winsorization, Turkey's hinge method. Here we are treating the outliers with Turkey's hinge method. Tukey's hinge method is a type of data transformation technique that involves Winsorizing a dataset at the 25th and 75th percentiles, also known as the hinges. The goal of Tukey's hinge method is to reduce the impact of outliers while preserving the central tendency and spread of the dataset.

# %%
for i in all_cont:
    q1 = np.percentile(df[i], 25)
    q3 = np.percentile(df[i], 75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    df[i] = np.where(df[i] > upper_bound, upper_bound,np.where(df[i] < lower_bound,lower_bound,df[i]))

# %%
outlier_findings(inpdata=df['Ram'])
# Out:
# Quartile 1 : 4.0 Quartile 3 : 8.0
# Inter Quartile Range : 4.0
# Min Whisker : -2.0 Max Whiker : 14.0
# Number of values below the lower bound: 0
# Number of values above the upper bound: 0

# %%
#df.columns

# %%
# df['Weight']=np.sqrt(df['Weight'])
# df['Ips']=np.sqrt(df['Ips'])

# %%
df['Touchscreen'].unique()
# Out:
# array([0.])

# %%
df.drop(['Touchscreen'],inplace=True,axis=1)

# %% [markdown]
# # Checking Correlation

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(), linewidths=1.0, annot=True, fmt=".2f", cmap='viridis')
plt.show
# Out:
# C:\Users\dipam\AppData\Local\Temp\ipykernel_9980\2948069209.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), linewidths=1.0, annot=True, fmt=".2f", cmap='viridis')
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'Ram', 'Gpu', 'Weight', 'Price', 'Ips',
#        'X_res', 'Y_res', 'pixel_per_inch', 'Cpu brand', 'os'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Company            object
# TypeName           object
# Inches            float64
# Ram               float64
# Gpu                object
# Weight            float32
# Price             float64
# Ips               float64
# X_res             float64
# Y_res             float64
# pixel_per_inch    float64
# Cpu brand          object
# os                 object
# dtype: object

# %%
df.drop(['X_res','Y_res'],inplace=True,axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
# the independent variables set
X = df[[ 'Inches', 'Ram','Weight',
        'Ips', 'pixel_per_inch']]
  
# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
print(vif_data)
# Out:
#           feature        VIF
# 0          Inches  94.847640
# 1             Ram   9.172096
# 2          Weight  41.896392
# 3             Ips   1.635711
# 4  pixel_per_inch  34.223635

# %%
from statsmodels.multivariate.factor_rotation import rotate_factors
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_scaled = scaler.fit_transform(df[['Inches', 'Ram', 'Weight','Ips', 'pixel_per_inch']])

pca = PCA(n_components=3)
pca.fit(df_scaled)

principal_components = pca.components_

rotated_components = rotate_factors(principal_components, method='varimax')
print("Rotated Components:")
print(rotated_components)

pca_scores = pca.transform(df_scaled)

print("PCA Scores:")
print(pca_scores)

print("PCA Explained Variance Ratio:")
print(pca.explained_variance_ratio_)
# Out:
# Rotated Components:
# (array([[-1.00000000e+00, -8.75413127e-09, -1.91197902e-05,
#         -4.12166724e-09,  1.58662113e-06],
#        [-8.75415094e-09,  1.00000000e+00, -1.42809874e-08,
#          1.59438077e-07, -1.84251836e-07],
#        [-4.12167023e-09, -1.59438078e-07,  9.06553531e-11,
#          1.00000000e+00, -1.61312433e-09]]), array([[ 0.61611857,  0.17179211, -0.68134844,  0.02853244,  0.3547331 ],
#        [ 0.05581376,  0.68460846, -0.07235956, -0.49446412, -0.52769822],
#        [ 0.5964661 ,  0.25324526,  0.72386864,  0.07078227,  0.22605108],
#        [-0.18324156,  0.50879221, -0.06855459,  0.82876882, -0.12647345],
#        [-0.47742377,  0.42284283,  0.04292846, -0.25064567,  0.72705184]]))
# PCA Scores:
# [[ 2.71120947  1.27604642  0.64987339]
#  [ 1.08500019 -0.97558053 -0.54385141]
#  [-0.21860159 -0.27208292 -0.55374166]
#  ...
#  [ 0.45241193 -2.25550322  0.4948879 ]
#  [-1.20068754 -1.13409281  0.13255931]
#  [-1.17816244 -1.53005392  0.42284365]]
# PCA Explained Variance Ratio:
# [0.45519534 0.30911683 0.15079742]

# %%
b=pd.DataFrame(pca_scores,columns=['PCA1','PCA2','PCA3'])

# %%
b.head()
# Out:
#        PCA1      PCA2      PCA3
# 0  2.711209  1.276046  0.649873
# 1  1.085000 -0.975581 -0.543851
# 2 -0.218602 -0.272083 -0.553742
# 3  1.231470  2.929855 -0.119752
# 4  2.711209  1.276046  0.649873

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'Ram', 'Gpu', 'Weight', 'Price', 'Ips',
#        'pixel_per_inch', 'Cpu brand', 'os'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'Ram', 'Gpu', 'Weight', 'Price', 'Ips',
#        'pixel_per_inch', 'Cpu brand', 'os'],
#       dtype='object')

# %%
df_new= pd.concat([df,b], axis=1)

# %%
df_new.head()
# Out:
#   Company   TypeName  Inches   Ram                           Gpu  Weight  \
# 0   Apple  Ultrabook    13.3   8.0  Intel Iris Plus Graphics 640    1.37
# 1   Apple  Ultrabook    13.3   8.0        Intel HD Graphics 6000    1.34
# 2      HP   Notebook    15.6   8.0         Intel HD Graphics 620    1.86
# 3   Apple  Ultrabook    15.4  14.0            AMD Radeon Pro 455    1.83
# 4   Apple  Ultrabook    13.3   8.0  Intel Iris Plus Graphics 650    1.37
#
#          Price  Ips  pixel_per_inch      Cpu brand                  os  \
# 0   71378.6832  1.0      202.372769  Intel Core i5                 Mac
# 1   47895.5232  0.0      127.677940  Intel Core i5                 Mac
# 2   30636.0000  0.0      141.211998  Intel Core i5  Others/No OS/Linux
# 3  135195.3360  1.0      202.372769  Intel Core i7                 Mac
# 4   96095.8080  1.0      202.372769  Intel Core i5                 Mac
#
#        PCA1      PCA2      PCA3
# 0  2.711209  1.276046  0.649873
# 1  1.085000 -0.975581 -0.543851
# 2 -0.218602 -0.272083 -0.553742
# 3  1.231470  2.929855 -0.119752
# 4  2.711209  1.276046  0.649873

# %%
df_new.drop(['Company','TypeName','Gpu','Cpu brand','os'],inplace=True,axis=1)

# %%
df_new.corr()[['PCA1','PCA2','PCA3']]
# Out:
#                         PCA1          PCA2          PCA3
# Inches         -9.294770e-01  2.135745e-01  2.477539e-02
# Ram            -8.420172e-02  8.511157e-01 -4.293553e-01
# Weight         -8.998694e-01  3.148383e-01  6.146193e-02
# Price           1.031549e-01  7.190713e-01 -3.083893e-01
# Ips             2.764461e-01  6.325384e-01  7.196400e-01
# pixel_per_inch  7.202582e-01  5.256844e-01 -2.176418e-01
# PCA1            1.000000e+00 -1.639996e-16  3.132141e-16
# PCA2           -1.639996e-16  1.000000e+00  1.431775e-16
# PCA3            3.132141e-16  1.431775e-16  1.000000e+00

# %%
df_new.head()
# Out:
#    Inches   Ram  Weight        Price  Ips  pixel_per_inch      PCA1      PCA2  \
# 0    13.3   8.0    1.37   71378.6832  1.0      202.372769  2.711209  1.276046
# 1    13.3   8.0    1.34   47895.5232  0.0      127.677940  1.085000 -0.975581
# 2    15.6   8.0    1.86   30636.0000  0.0      141.211998 -0.218602 -0.272083
# 3    15.4  14.0    1.83  135195.3360  1.0      202.372769  1.231470  2.929855
# 4    13.3   8.0    1.37   96095.8080  1.0      202.372769  2.711209  1.276046
#
#        PCA3
# 0  0.649873
# 1 -0.543851
# 2 -0.553742
# 3 -0.119752
# 4  0.649873

# %%
#df_new.drop(['Inches', 'Ram', 'Weight', 'Touchscreen', 'Ips', 'pixel_per_inch'],inplace=True,axis=1)

# %%
df_new.columns
# Out:
# Index(['Inches', 'Ram', 'Weight', 'Price', 'Ips', 'pixel_per_inch', 'PCA1',
#        'PCA2', 'PCA3'],
#       dtype='object')

# %%
#No values found beyond 10 hence we can proceed further.

# %% [markdown]
# # Spliting Data

# %%
df_dummies=pd.get_dummies(df_new,drop_first=True)

# %%
X = df_dummies.drop(columns=['Price'])
y = np.log(df_dummies['Price'])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X.columns
# Out:
# Index(['Inches', 'Ram', 'Weight', 'Ips', 'pixel_per_inch', 'PCA1', 'PCA2',
#        'PCA3'],
#       dtype='object')

# %% [markdown]
# # Feature Selection

# %%
# from sklearn.feature_selection import RFECV
# from sklearn.linear_model import LinearRegression
# model = LinearRegression()
# rfe = RFECV(estimator=model,cv=5,step=1)
# rfe.fit(X, y)
# selected_features = np.where(rfe.support_)[0]
# print("Selected feature indices:", selected_features.tolist())

# %%
# column_names = df_dummies.columns.tolist()
# index_numbers = selected_features 
# selected_columns = [column_names[i] for i in index_numbers]
# print("Selected columns:", selected_columns)

# %%
# After doing feature selection performance of models get reduced so we will perform with all the features.

# %% [markdown]
# # Statistical Model-OLS

# %%
import statsmodels.api as sm
X_train = sm.add_constant(X_train)
model = sm.OLS(y_train, X_train)
results = model.fit()
p_values = results.pvalues
selected_features = X_train.columns[p_values <= 0.05]
X_train_filtered = X_train[selected_features]
model_filtered = sm.OLS(y_train, X_train_filtered)
results_filtered = model_filtered.fit()
print(results_filtered.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.871
# Model:                            OLS   Adj. R-squared:                  0.865
# Method:                 Least Squares   F-statistic:                     131.8
# Date:                Tue, 27 Jun 2023   Prob (F-statistic):               0.00
# Time:                        22:23:28   Log-Likelihood:                 103.18
# No. Observations:                1107   AIC:                            -96.37
# Df Residuals:                    1052   BIC:                             179.2
# Df Model:                          54
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                              7.1575      0.047    152.719      0.000       7.066       7.250
# Ram                                0.0442      0.003     13.950      0.000       0.038       0.050
# pixel_per_inch                     0.0046      0.000     14.181      0.000       0.004       0.005
# Company_Apple                      2.4932      0.048     52.389      0.000       2.400       2.587
# Company_Chuwi                     -0.4477      0.169     -2.653      0.008      -0.779      -0.117
# Company_Dell                       0.0798      0.022      3.648      0.000       0.037       0.123
# Company_HP                         0.1146      0.022      5.099      0.000       0.071       0.159
# Company_LG                         0.4146      0.133      3.117      0.002       0.154       0.676
# Company_Lenovo                     0.0294      0.021      1.389      0.165      -0.012       0.071
# Company_MSI                        0.0917      0.042      2.207      0.028       0.010       0.173
# Company_Mediacom                  -0.2944      0.107     -2.760      0.006      -0.504      -0.085
# Company_Toshiba                    0.2017      0.040      5.017      0.000       0.123       0.281
# Company_Vero                      -0.5813      0.136     -4.284      0.000      -0.848      -0.315
# TypeName_Gaming                   -0.1220      0.047     -2.589      0.010      -0.214      -0.030
# TypeName_Notebook                 -0.1178      0.026     -4.507      0.000      -0.169      -0.067
# TypeName_Ultrabook                 0.1217      0.029      4.235      0.000       0.065       0.178
# TypeName_Workstation               0.4848      0.055      8.838      0.000       0.377       0.592
# Gpu_AMD FirePro W5130M          1.724e-15   2.86e-16      6.029      0.000    1.16e-15    2.29e-15
# Gpu_AMD FirePro W6150M             0.4128      0.232      1.781      0.075      -0.042       0.867
# Gpu_AMD R4 Graphics             4.709e-16   2.11e-16      2.237      0.026    5.78e-17    8.84e-16
# Gpu_AMD Radeon 520                -0.2745      0.067     -4.113      0.000      -0.406      -0.144
# Gpu_AMD Radeon 530                -0.1214      0.039     -3.118      0.002      -0.198      -0.045
# Gpu_AMD Radeon R2                 -0.5856      0.132     -4.425      0.000      -0.845      -0.326
# Gpu_AMD Radeon R2 Graphics        -0.4036      0.115     -3.507      0.000      -0.629      -0.178
# Gpu_AMD Radeon R4                 -0.2845      0.161     -1.765      0.078      -0.601       0.032
Durbin-Watson:                   1.918
# Prob(Omnibus):                  0.107   Jarque-Bera (JB):                4.811
# Skew:                           0.084   Prob(JB):                       0.0902
# Kurtosis:                       3.276   Cond. No.                     2.32e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.32e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
from sklearn.metrics import mean_squared_error, r2_score
X_test = sm.add_constant(X_test)
X_test_filtered = X_test[selected_features]
y_pred_test = results_filtered.predict(X_test_filtered)
r2_test = r2_score(y_test, y_pred_test)
print("Test Set - R-squared (R2):", r2_test)
# Out:
# Test Set - R-squared (R2): 0.8611799807879951

# %%
error=y_pred_test-y_test

# %%
#Durbin Watson- Value almost close to 2 but there is some presence of autocorrelation.
#Omnibus-Overall data is normall distributed as from the p value we have to acceptnull hypothesis.
#Jarque-Bera-Standout,where h0 is the skewness and kurtosis is behaving normal.
#Skewness-Slightly negatively skewd.
#Kurtosis-Data is concentrated more heavily around the mean.As the pekdness is high.
#Annova-Atleast one pair of group have significant difference in mean laptop price,so f statistics standout.

# %%
sns.histplot(data=error)
# Out:
# <Axes: ylabel='Count'>

# %%
import scipy.stats as stats
stats.probplot(error, dist="norm", plot=plt)
plt.xlabel("Theoretical Quantiles")
plt.ylabel("Sample Quantiles")
plt.title("QQ Plot of Error")
plt.show()

# %%
#One of the assumption of ols is satisfied errors are normally distributed

# %%
#X_train_filtered

# %% [markdown]
# # Random Forest

# %%
df_dummies1=pd.get_dummies(df,drop_first=True)

# %%
X = df_dummies1.drop(columns=['Price'])
y = np.log(df_dummies1['Price'])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score,mean_squared_error

rf_model = RandomForestRegressor(n_estimators=500,max_depth=15,min_samples_leaf=1,min_samples_split=5)

rf_model.fit(X_train, y_train)

y_pred_train = rf_model.predict(X_train)
y_pred_test = rf_model.predict(X_test)


mae_train = mean_squared_error(y_train, y_pred_train)
mae_train1=np.sqrt(mae_train)
mae_test = mean_squared_error(y_test, y_pred_test)
mae_test1=np.sqrt(mae_test)
r2_train = r2_score(y_train, y_pred_train)
r2_test = r2_score(y_test, y_pred_test)

print("Train Set - RMSE:", mae_train1)
print("Train Set - R-squared (R2):", r2_train)
print("Test Set - RMSE:",mae_test1 )
print("Test Set - R-squared (R2):", r2_test)
# Out:
# Train Set - MAE: 0.10915734160091621
# Train Set - R-squared (R2): 0.9684260791183152
# Test Set - MAE: 0.20435463503835632
# Test Set - R-squared (R2): 0.8902038602006782

# %% [markdown]
# # Feature Importance

# %%
from sklearn.ensemble import RandomForestRegressor
import numpy as np
regressor = RandomForestRegressor()
regressor.fit(X_train, y_train)
importances = regressor.feature_importances_
indices = np.argsort(importances)[::-1]
print("Feature ranking:")
for f in range(10):
    print(f"{f + 1}. Feature {indices[f]}: {importances[indices[f]]}")
    
import matplotlib.pyplot as plt

plt.figure()
plt.title("Top 10 Feature Importance")
plt.bar(range(10), importances[indices[:10]], color="g", align="center")
plt.xticks(range(10), indices[:10])
plt.xlim([-1, 10])
plt.show()
# Out:
# Feature ranking:
# 1. Feature 1: 0.5815061727579173
# 2. Feature 140: 0.06535570727147283
# 3. Feature 2: 0.06059920887039881
# 4. Feature 4: 0.059247323825425524
# 5. Feature 25: 0.05129784313306863
# 6. Feature 0: 0.03159097728538009
# 7. Feature 138: 0.021975856730990014
# 8. Feature 139: 0.013433860499284543
# 9. Feature 27: 0.010657301615753312
# 10. Feature 141: 0.007904724063670146

# %%
column_names = df_dummies1.columns.tolist()
index_numbers = [1,140,2,4,25,138,139,27,141]  
selected_columns = [column_names[i] for i in index_numbers]
print("Selected columns:", np.array(selected_columns))
# Out:
# Selected columns: ['Ram' 'Cpu brand_Intel Core i7' 'Weight' 'Ips' 'TypeName_Netbook'
#  'Cpu brand_Intel Core i3' 'Cpu brand_Intel Core i5' 'TypeName_Ultrabook'
#  'Cpu brand_Other Intel Processor']

# %% [markdown]
# # Optuna Performing

# %%
import optuna
def objective(trial):
    # Define the hyperparameters to tune
    n_estimators = trial.suggest_int('n_estimators', 100, 1000, step=100)
    max_depth = trial.suggest_int('max_depth', 5, 15)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 5)
    
    regressor = RandomForestRegressor(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        random_state=42
    )
    regressor.fit(X_train, y_train)

    y_pred = regressor.predict(X_test)

    mse_test = mean_squared_error(y_test, y_pred)
    rmse_test=np.sqrt(mse_test)
    return rmse_test
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=20)

best_params = study.best_params
best_value = study.best_value
print("Best Parameters: ", best_params)
print("Best Value: ", best_value)
# Out:
# [I 2023-06-25 05:58:13,893] A new study created in memory with name: no-name-26feedad-a19c-4e39-aad4-961f412772be
# [I 2023-06-25 05:58:14,965] Trial 0 finished with value: 0.22993630470435872 and parameters: {'n_estimators': 200, 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.22993630470435872.
# [I 2023-06-25 05:58:17,048] Trial 1 finished with value: 0.24021604850981781 and parameters: {'n_estimators': 400, 'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.22993630470435872.
# [I 2023-06-25 05:58:21,865] Trial 2 finished with value: 0.22031206631562733 and parameters: {'n_estimators': 800, 'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 2 with value: 0.22031206631562733.
# [I 2023-06-25 05:58:26,599] Trial 3 finished with value: 0.23936015151581455 and parameters: {'n_estimators': 1000, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 4}. Best is trial 2 with value: 0.22031206631562733.
# [I 2023-06-25 05:58:31,386] Trial 4 finished with value: 0.22191138700039056 and parameters: {'n_estimators': 900, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 2 with value: 0.22031206631562733.
# [I 2023-06-25 05:58:33,062] Trial 5 finished with value: 0.230815907522013 and parameters: {'n_estimators': 400, 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 2 with value: 0.22031206631562733.
# [I 2023-06-25 05:58:36,770] Trial 6 finished with value: 0.23492321712893727 and parameters: {'n_estimators': 800, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 2 with value: 0.22031206631562733.
# [I 2023-06-25 05:58:37,763] Trial 7 finished with value: 0.2181919711876539 and parameters: {'n_estimators': 200, 'max_depth': 11, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 7 with value: 0.2181919711876539.
# [I 2023-06-25 05:58:40,298] Trial 8 finished with value: 0.24036604062843217 and parameters: {'n_estimators': 600, 'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 5}. Best is trial 7 with value: 0.2181919711876539.
# [I 2023-06-25 05:58:41,890] Trial 9 finished with value: 0.23988372767516422 and parameters: {'n_estimators': 400, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 7 with value: 0.2181919711876539.
# [I 2023-06-25 05:58:42,248] Trial 10 finished with value: 0.2578896908849041 and parameters: {'n_estimators': 100, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 7 with value: 0.2181919711876539.
# [I 2023-06-25 05:58:45,902] Trial 11 finished with value: 0.21900212979899622 and parameters: {'n_estimators': 700, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 7 with value: 0.2181919711876539.
# [I 2023-06-25 05:58:49,053] Trial 12 finished with value: 0.21840448043548827 and parameters: {'n_estimators': 600, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 7 with value: 0.2181919711876539.
# [I 2023-06-25 05:58:51,655] Trial 13 finished with value: 0.21924268621402443 and parameters: {'n_estimators': 500, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 7 with value: 0.2181919711876539.
# [I 2023-06-25 05:58:52,400] Trial 14 finished with value: 0.24786098198712042 and parameters: {'n_estimators': 200, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 7 with value: 0.2181919711876539.
# [I 2023-06-25 05:58:55,494] Trial 15 finished with value: 0.21820878537200392 and parameters: {'n_estimators': 600, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 7 with value: 0.2181919711876539.
# [I 2023-06-25 05:58:57,099] Trial 16 finished with value: 0.2230933365598469 and parameters: {'n_estimators': 300, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 7 with value: 0.2181919711876539.
# [I 2023-06-25 05:58:57,567] Trial 17 finished with value: 0.23464484503544814 and parameters: {'n_estimators': 100, 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 7 with value: 0.2181919711876539.
# [I 2023-06-25 05:58:59,826] Trial 18 finished with value: 0.2390373201651061 and parameters: {'n_estimators': 500, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 4}. Best is trial 7 with value: 0.2181919711876539.
# [I 2023-06-25 05:59:03,487] Trial 19 finished with value: 0.22110385145537878 and parameters: {'n_estimators': 700, 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 7 with value: 0.2181919711876539.
# Best Parameters:  {'n_estimators': 200, 'max_depth': 11, 'min_samples_split': 6, 'min_samples_leaf': 1}
# Best Value:  0.2181919711876539

# %%
#!pip install shap

# %% [markdown]
# # Explanaible AI Framework SHAP

# %%
import shap
explainer = shap.Explainer(rf_model)
shap_values1 = explainer.shap_values(X_test)

# %%
shap.summary_plot(shap_values1, X_test)
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
explanation = shap.Explanation(shap_values1)
shap.plots.bar(explanation)

# %%
column_names = df_dummies1.columns.tolist()
index_numbers = [1,25,140,2,4,138,139]  
selected_columns = [column_names[i] for i in index_numbers]
print("Selected columns:", np.array(selected_columns))
# Out:
# Selected columns: ['Ram' 'TypeName_Netbook' 'Cpu brand_Intel Core i7' 'Weight' 'Ips'
#  'Cpu brand_Intel Core i3' 'Cpu brand_Intel Core i5']

# %% [markdown]
# #Higher the Ram,cpu brand,Notebbok type value higher will be the laptop price,also from beeswarm chart we can see that the the most influencing factor is Ram,higher the Ram value more the laptop price will be.
#
# #increase the laptop value.While the other brands of cpu intel brans negatively impact on laptop price,people love to pay only for i5 or i7.

# %%
instance_index = [15, 89]
for i in instance_index:
    base_value = explainer.expected_value
    shap_values_instance = shap_values1[i]
    shap.force_plot(base_value, shap_values_instance, X_test.iloc[i], matplotlib=True)

# %%
#For one instances we can see from the force plot cpu brand i7,cpu brand intel processor has the higher impact on predicting the laptop price.
#TypeName_Notebook,weight lower effect on predicting price

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score,mean_squared_error

DTR_model = DecisionTreeRegressor(max_depth=12,min_samples_leaf=2,min_samples_split=15)

DTR_model.fit(X_train, y_train)

y_pred_train = DTR_model.predict(X_train)
y_pred_test = DTR_model.predict(X_test)


mae_train = mean_squared_error(y_train, y_pred_train)
mae_train1=np.sqrt(mae_train)
mae_test = mean_squared_error(y_test, y_pred_test)
mae_test1=np.sqrt(mae_test)
r2_train = r2_score(y_train, y_pred_train)
r2_test = r2_score(y_test, y_pred_test)

print("Train Set - RMSE:", mae_train1)
print("Train Set - R-squared (R2):", r2_train)
print("Test Set - RMSE:",mae_test1 )
print("Test Set - R-squared (R2):", r2_test)
# Out:
# Train Set - RMSE: 0.16713095124232732
# Train Set - R-squared (R2): 0.9259821636946537
# Test Set - RMSE: 0.23085475542040976
# Test Set - R-squared (R2): 0.859881417033362

# %%
import optuna
def objective(trial):
    max_depth = trial.suggest_int('max_depth', 5, 18)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 15)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 5)
    
    regressor = DecisionTreeRegressor(
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        random_state=42
    )
    regressor.fit(X_train, y_train)

    y_pred = regressor.predict(X_test)

    mse_test = mean_squared_error(y_test, y_pred)
    rmse_test=np.sqrt(mse_test)
    return rmse_test
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)
max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 20 with value: 0.23728817219001047.
# [I 2023-06-25 05:59:17,749] Trial 29 finished with value: 0.26697352813725617 and parameters: {'max_depth': 17, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.23728817219001047.
# [I 2023-06-25 05:59:17,781] Trial 30 finished with value: 0.2533376715466391 and parameters: {'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.23728817219001047.
# [I 2023-06-25 05:59:17,817] Trial 31 finished with value: 0.2375032453876532 and parameters: {'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.23728817219001047.
# [I 2023-06-25 05:59:17,859] Trial 32 finished with value: 0.24637006908407147 and parameters: {'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.23728817219001047.
# [I 2023-06-25 05:59:17,907] Trial 33 finished with value: 0.26198918425388007 and parameters: {'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 5}. Best is trial 20 with value: 0.23728817219001047.
# [I 2023-06-25 05:59:17,941] Trial 34 finished with value: 0.23728817219001047 and parameters: {'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.23728817219001047.
# [I 2023-06-25 05:59:17,982] Trial 35 finished with value: 0.26875301402494584 and parameters: {'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 20 with value: 0.23728817219001047.
# [I 2023-06-25 05:59:18,019] Trial 36 finished with value: 0.2525206381398377 and parameters: {'max_depth': 13, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.23728817219001047.
# [I 2023-06-25 05:59:18,065] Trial 37 finished with value: 0.23991651273217232 and parameters: {'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.23728817219001047.
# [I 2023-06-25 05:59:18,109] Trial 38 finished with value: 0.24640883448659176 and parameters: {'max_depth': 13, 'min_samples_split': 13, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.23728817219001047.
# [I 2023-06-25 05:59:18,147] Trial 39 finished with value: 0.2533376715466391 and parameters: {'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.23728817219001047.
# [I 2023-06-25 05:59:18,185] Trial 40 finished with value: 0.2732111065643641 and parameters: {'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 3}. Best is trial 20 with value: 0.23728817219001047.
# [I 2023-06-25 05:59:18,217] Trial 41 finished with value: 0.2375032453876532 and parameters: {'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.23728817219001047.
# [I 2023-06-25 05:59:18,267] Trial 42 finished with value: 0.24734041920850805 and parameters: {'max_depth': 11, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.23728817219001047.
# [I 2023-06-25 05:59:18,314] Trial 43 finished with value: 0.24158356372939405 and parameters: {'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.23728817219001047.
# [I 2023-06-25 05:59:18,354] Trial 44 finished with value: 0.24282713283331192 and parameters: {'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.23728817219001047.
# [I 2023-06-25 05:59:18,389] Trial 45 finished with value: 0.24203087093969003 and parameters: {'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.23728817219001047.
# [I 2023-06-25 05:59:18,434] Trial 46 finished with value: 0.28899472642601376 and parameters: {'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 4}. Best is trial 20 with value: 0.23728817219001047.
# [I 2023-06-25 05:59:18,468] Trial 47 finished with value: 0.27286737149441453 and parameters: {'max_depth': 14, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 20 with value: 0.23728817219001047.
# [I 2023-06-25 05:59:18,521] Trial 48 finished with value: 0.2661057402717873 and parameters: {'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.23728817219001047.
# [I 2023-06-25 05:59:18,568] Trial 49 finished with value: 0.24589489457724617 and parameters: {'max_depth': 12, 'min_samples_split': 9, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.23728817219001047.
# Best Parameters:  {'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 2}
# Best Value:  0.23728817219001047

# %%
from sklearn.tree import DecisionTreeRegressor
import numpy as np
regressor = DecisionTreeRegressor()
regressor.fit(X_train, y_train)
importances = regressor.feature_importances_
indices = np.argsort(importances)[::-1]
print("Feature ranking:")
for f in range(10):
    print(f"{f + 1}. Feature {indices[f]}: {importances[indices[f]]}")
    
import matplotlib.pyplot as plt

plt.figure()
plt.title("Top 10 Feature Importance")
plt.bar(range(10), importances[indices[:10]], color="g", align="center")
plt.xticks(range(10), indices[:10])
plt.xlim([-1, 10])
plt.show()
# Out:
# Feature ranking:
# 1. Feature 139: 0.3624059287391125
# 2. Feature 138: 0.1889772154545417
# 3. Feature 1: 0.10549503193250398
# 4. Feature 4: 0.08712991781978824
# 5. Feature 25: 0.04943164980395585
# 6. Feature 140: 0.02522614758674925
# 7. Feature 27: 0.022778962174055662
# 8. Feature 142: 0.01852222019283522
# 9. Feature 64: 0.01130553631638643
# 10. Feature 106: 0.009757747486073323

# %%
column_names = df_dummies.columns.tolist()
index_numbers = [139,138,4,25,140,27,141,64,106]  
selected_columns = [column_names[i] for i in index_numbers]
print("Selected columns:", np.array(selected_columns))
# Out:
# Selected columns: ['Cpu brand_Intel Core i7' 'Cpu brand_Intel Core i5' 'pixel_per_inch'
#  'TypeName_Notebook' 'Cpu brand_Other Intel Processor'
#  'TypeName_Workstation' 'os_Others/No OS/Linux' 'Gpu_AMD Radeon RX 580'
#  'Gpu_Nvidia GeForce GTX 1060']

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error,r2_score,mean_squared_error

knn_model = KNeighborsRegressor(n_neighbors=3)

knn_model.fit(X_train, y_train)

y_pred_train = knn_model.predict(X_train)
y_pred_test = knn_model.predict(X_test)

mae_train = mean_squared_error(y_train, y_pred_train)
mae_train1=np.sqrt(mae_train)
mae_test = mean_squared_error(y_test, y_pred_test)
mae_test1=np.sqrt(mae_test)
r2_train = r2_score(y_train, y_pred_train)
r2_test = r2_score(y_test, y_pred_test)

print("Train Set - RMSE:", mae_train1)
print("Train Set - R-squared (R2):", r2_train)
print("Test Set - RMSE:",mae_test1 )
print("Test Set - R-squared (R2):", r2_test)
# Out:
# Train Set - RMSE: 0.16379147333067232
# Train Set - R-squared (R2): 0.9289105434004628
# Test Set - RMSE: 0.2658805501486599
# Test Set - R-squared (R2): 0.8141377356333128

# %%
k_values = []
rmse_values = []
for k in range(1, 21):
    knn_model = KNeighborsRegressor(n_neighbors=k)
    knn_model.fit(X_train, y_train)
    y_pred = knn_model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    k_values.append(k)
    rmse_values.append(rmse)
# Plot the RMSE values against the number of neighbors (k)
plt.plot(k_values, rmse_values, marker='o')
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('RMSE')
plt.title('Elbow Method - KNN Model')
plt.show()

# %%
# Ideal k from the graph we can see that 3,where drastically decreased after that RMSE increased

# %% [markdown]
# # Adaboost

# %%
from sklearn.metrics import mean_squared_error, r2_score,mean_squared_error
from sklearn.ensemble import AdaBoostRegressor
import math 

Ada_model = AdaBoostRegressor(n_estimators=300, learning_rate=0.029792329343184265, loss='exponential')

Ada_model.fit(X_train, y_train)

y_pred_train = Ada_model.predict(X_train)
y_pred_test = Ada_model.predict(X_test)

mae_train = mean_squared_error(y_train, y_pred_train)
mae_train1=np.sqrt(mae_train)
mae_test = mean_squared_error(y_test, y_pred_test)
mae_test1=np.sqrt(mae_test)
r2_train = r2_score(y_train, y_pred_train)
r2_test = r2_score(y_test, y_pred_test)

print("Train Set - RMSE:", mae_train1)
print("Train Set - R-squared (R2):", r2_train)
print("Test Set - RMSE:",mae_test1 )
print("Test Set - R-squared (R2):", r2_test)
# Out:
# Train Set - RMSE: 0.28114152019931304
# Train Set - R-squared (R2): 0.7905537479478565
# Test Set - RMSE: 0.286108105162364
# Test Set - R-squared (R2): 0.7847820904739139

# %%
import optuna
def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 100, 1000, step=100)
    learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.2)
    loss = trial.suggest_categorical('loss', ['linear', 'square', 'exponential'])
    
    regressor = AdaBoostRegressor(
        n_estimators=n_estimators,
        learning_rate=learning_rate,
        loss=loss,
        random_state=42
    )
    regressor.fit(X_train, y_train)

    y_pred = regressor.predict(X_test)

    mse = mean_squared_error(y_test, y_pred)
    return mse

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=20)

best_params = study.best_params
best_value = study.best_value
print("Best Parameters: ", best_params)
print("Best Value: ", best_value)
# Out:
# [I 2023-06-25 05:59:22,175] A new study created in memory with name: no-name-a803ef0c-6606-4090-a6b1-0bf9868021db
# suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
# [I 2023-06-25 05:59:25,273] Trial 0 finished with value: 0.09945241406625663 and parameters: {'n_estimators': 600, 'learning_rate': 0.015223850407245852, 'loss': 'linear'}. Best is trial 0 with value: 0.09945241406625663.
# suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
# [I 2023-06-25 05:59:29,631] Trial 1 finished with value: 0.11763549478858823 and parameters: {'n_estimators': 800, 'learning_rate': 0.12690974803985458, 'loss': 'exponential'}. Best is trial 0 with value: 0.09945241406625663.
# suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
# [I 2023-06-25 05:59:31,817] Trial 2 finished with value: 0.11208167225035326 and parameters: {'n_estimators': 300, 'learning_rate': 0.15663152397600974, 'loss': 'linear'}. Best is trial 0 with value: 0.09945241406625663.
# suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
# [I 2023-06-25

# suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
# [I 2023-06-25 06:00:28,110] Trial 19 finished with value: 0.09944271849356606 and parameters: {'n_estimators': 100, 'learning_rate': 0.04047578647365009, 'loss': 'square'}. Best is trial 10 with value: 0.09775009223345534.
# Best Parameters:  {'n_estimators': 700, 'learning_rate': 0.011286006740599038, 'loss': 'linear'}
# Best Value:  0.09775009223345534

# %%
X_test.columns
# Out:
# Index(['const', 'Weight', 'Touchscreen', 'Ips', 'pixel_per_inch',
#        'Company_Apple', 'Company_Asus', 'Company_Chuwi', 'Company_Dell',
#        'Company_Fujitsu',
#        ...
#        'Gpu_Nvidia Quadro M500M', 'Gpu_Nvidia Quadro M520M',
#        'Gpu_Nvidia Quadro M620', 'Gpu_Nvidia Quadro M620M',
#        'Cpu brand_Intel Core i3', 'Cpu brand_Intel Core i5',
#        'Cpu brand_Intel Core i7', 'Cpu brand_Other Intel Processor',
#        'os_Others/No OS/Linux', 'os_Windows'],
#       dtype='object', length=143)

# %%
# Select a random subset of 50 samples from X_test
random_indices = np.random.choice(X_test.shape[0], 100, replace=False)
X_test_subset = X_test.iloc[random_indices]

feature_names = X_test.columns

random_train_indices = np.random.choice(X_train.shape[0], 200, replace=False)
X_train_subset = X_train.iloc[random_train_indices]
background = shap.sample(X_train_subset, 100)

explainer = shap.KernelExplainer(Ada_model.predict, background)
explainer.feature_names = feature_names

shap_values = explainer.shap_values(X_test_subset)
# Out:
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   0%|          | 0/100 [00:00<?, ?it/s]
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
# X does not have valid feature names, but AdaBoostRegressor was fitted with feature names

# %%
shap.summary_plot(shap_values, X_test_subset)
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
explanation = shap.Explanation(shap_values)
shap.plots.bar(explanation)

# %%
column_names = df_dummies1.columns.tolist()
index_numbers = [1,25,138,139,4]  
selected_columns = [column_names[i] for i in index_numbers]
print("Selected columns:", np.array(selected_columns))
# Out:
# Selected columns: ['Ram' 'TypeName_Netbook' 'Cpu brand_Intel Core i3'
#  'Cpu brand_Intel Core i5' 'Ips']

# %%
#Same result we can see from the Adaboost model.Mainly Ram,Type_Notebook,Intel Cpu contribute more towards predicting laptop price

# %% [markdown]
# # Conclusion

# %%
import matplotlib.pyplot as plt
models = ['Adaboost', 'KNN', 'Random Forest', 'OLS','Decision Tree']
r2_values = [0.730, 0.825, 0.892, 0.871,0.844]
plt.bar(models, r2_values)
plt.xlabel('Models')
plt.ylabel('R-squared (R2)')
plt.title('Comparison of R-squared (R2) Values')
plt.show()

# %% [markdown]
# From the above comparision chart we can conclude that the Random Forest gives the result and we can get the Idea which are features
# most influencial to predict the outcome,From the random forest MAE came 0.15 that means with difference of actual values,for an example
# if we consider laptop prices are in dollar that means there is average difference of 15 dollar with the actual values of from the predicted values.

# %% [markdown]
# Ram,Type_Notebook,Intel Processor is the top most influencial feature for laptop price.

# %% [markdown]
# Q1-Ans-absBy accurately predicting laptop prices, businesses can determine the optimal price point that maximizes profitability and sales

# %% [markdown]
# Q2-Ans-Ram is the top most influencial feature for laptop price apart from these there are also few factors which influence the pricing.

# %% [markdown]
# Q3-Ans-Accurate predictions help optimize pricing strategies, understand the price elasticity of demand, assess the impact of price changes, and gain a competitive edge in the market
